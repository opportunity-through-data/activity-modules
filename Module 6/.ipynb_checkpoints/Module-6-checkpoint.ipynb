# %% [markdown]
# # Module 6: Pandas, Visualization
# ### NBA Tweets Exploration
#
# Dataset: https://www.kaggle.com/mcdonalds/nutrition-facts

# %%
#maybe add a description for the dataset linked above? 

#This module is quite long. we should add section headings so that students 
#can have the easiest time getting help on their questions and separating their learning

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

pd.set_option('display.max_columns', None)

# %%
locations = pd.read_csv("nbatweets/locations.csv")
locations.head()
# Out:
#    Unnamed: 0         lon        lat
# 0           1  121.171039  14.996784
# 1           2  -77.094709  38.984652
# 2           3   -3.703790  40.416775
# 3           8  -83.753428   9.748917
# 4          11  -77.066923  39.153163

# %%
tweets = pd.read_csv("nbatweets/TweetsNBA.csv", encoding = "ISO-8859-1")
tweets.head()
# Out:
#    Unnamed: 0                                               text  \
# 0           1  RT @cavs: #NBAFinals GAME 3 STARTERS:\r\n\r\n@...
# 1           2  Ja comecou e eu no onibus  https://t.co/wPgRLw...
# 2           3    lets go Cavs\r\n#WhateverItTakes \r\n#NBAFinals
# 3           4  RT @cavs: #NBAFinals GAME 3 STARTERS:\r\n\r\n@...
# 4           5  RT @NBA:  Count down @StephenCurry30's TOP 5 t...
#
#    retweet_count  favorite_count  favorited  truncated               id_str  \
# 0              0               0      False      False  1004531741216989191
# 1              0               0      False      False  1004531741422481409
# 2              0               0      False      False  1004531741954981888
# 3              0               0      False      False  1004531743410573312
# 4              0               0      False      False  1004531743272194048
#
#   in_reply_to_screen_name                                             source  \
# 0                     NaN  <a href="http://twitter.com/download/iphone" r...
# 1                     NaN  <a href="http://twitter.com/download/android" ...
# 2                     NaN  <a href="http://twitter.com/download/android" ...
# 3                     NaN  <a href="http://twitter.com/download/android" ...
# 4                     NaN  <a href="http://twitter.com/download/iphone" r...
#
#    retweeted                      created_at  in_reply_to_status_id_str  \
# 0      False  Thu Jun 07 01:13:25 +0000 2018                        NaN
# 1      False  Thu Jun 07 01:13:25 +0000 2018                        NaN
# 2      False  Thu Jun 07 01:13:25 +0000 2018                        NaN
# 3      False  Thu Jun 07 01:13:25 +0000 2018                        NaN
# 4      False  Thu Jun 07 01:13:25 +0000 2018                        NaN
#
#    in_reply_to_user_id_str lang  listed_count  verified  \
# 0                      NaN   en             7     False
# 1                      NaN   pt             1     False
# 2                      NaN   en             0     False
# 3                      NaN   en             4     False
# 4                      NaN   en             1     False
#
#                   location         user_id_str  \
# 0                      NaN           234888800
# 1   Rio de Janeiro, Brasil  860068072983592964
# 2  Naga City, Bicol Region  878451665258414080
# 3          Niterói, Brasil          3473700207
# 4             Lawrence, MA  951834224646086656
#
#                                          description  geo_enabled  \
# 0  I am Ava :)) ?I LOVE #TWD #FTWD just a gal ???...         True
# 1  +5521?2.0\r\n Flamenguista  nao sou so mais um...         True
# 2                                                NaN        False
# 3                                          @Flamengo        False
# 4                                                22?         True
#
#                   user_created_at  statuses_count  followers_count  \
# 0  Thu Jan 06 20:41:19 +0000 2011            5860              285
# 1  Thu May 04 09:46:22 +0000 2017            2200              113
# 2  Sat Jun 24 03:16:12 +0000 2017             578              380
# 3  Fri Aug 28 21:58:35 +0000 2015           67308              520
# 4  Fri Jan 12 15:12:18 +0000 2018           10357              805
#
#    favourites_count  protected                        user_url      name  \
# 0             12836      False                             NaN       Ava
# 1              1963      False                             NaN  Markinho
# 2               736      False  http://Instagram.com/wrenzjudd  WR E N Z
# 3             17161      False                             NaN        GB
# 4              4057      False                             NaN        NG
#
#    time_zone user_lang  utc_offset  friends_count      screen_name  \
# 0        NaN        en         NaN            806        avakrutko
# 1        NaN        pt         NaN            119      Marcoosloco
# 2        NaN        en         NaN            319       wrenzberja
# 3        NaN        pt         NaN            171  duartegabriel35
# 4        NaN        en         NaN            326         NgDaizha
#
#   country_code country place_type full_name place_name place_id  place_lat  \
# 0          NaN     NaN        NaN       NaN        NaN      NaN        NaN
# 1          NaN     NaN        NaN       NaN        NaN      NaN        NaN
# 2          NaN     NaN        NaN       NaN        NaN      NaN        NaN
# 3          NaN     NaN        NaN       NaN        NaN      NaN        NaN
# 4          NaN     NaN        NaN       NaN        NaN      NaN        NaN
#
#    place_lon  lat  lon                                       expanded_url  \
# 0        NaN  NaN  NaN                                                NaN
# 1        NaN  NaN  NaN  https://twitter.com/NBA/status/100447552030887...
# 2        NaN  NaN  NaN                                                NaN
# 3        NaN  NaN  NaN                                                NaN
# 4        NaN  NaN  NaN                                                NaN
#
#                        url
# 0                      NaN
# 1  https://t.co/wPgRLwdg1O
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
len(tweets)
# Out:
# 51425

# %%
tweets.columns
# Out:
# Index(['Unnamed: 0', 'text', 'retweet_count', 'favorite_count', 'favorited',
#        'truncated', 'id_str', 'in_reply_to_screen_name', 'source', 'retweeted',
#        'created_at', 'in_reply_to_status_id_str', 'in_reply_to_user_id_str',
#        'lang', 'listed_count', 'verified', 'location', 'user_id_str',
#        'description', 'geo_enabled', 'user_created_at', 'statuses_count',
#        'followers_count', 'favourites_count', 'protected', 'user_url', 'name',
#        'time_zone', 'user_lang', 'utc_offset', 'friends_count', 'screen_name',
#        'country_code', 'country', 'place_type', 'full_name', 'place_name',
#        'place_id', 'place_lat', 'place_lon', 'lat', 'lon', 'expanded_url',
#        'url'],
#       dtype='object')

# %%
tweets.drop(axis=1, labels="text")
# Out:
#        Unnamed: 0  retweet_count  favorite_count  favorited  truncated  \
# 0               1              0               0      False      False
# 1               2              0               0      False      False
# 2               3              0               0      False      False
# 3               4              0               0      False      False
# 4               5              0               0      False      False
# 5               6              0               0      False      False
# 6               7              0               0      False      False
# 7               8              0               0      False      False
# 8               9              0               0      False      False
# 9              10              0               0      False      False
# 10             11              0               0      False      False
# 11             12              0               0      False      False
# 12             13              0               0      False      False
# 13             14              0               0      False      False
# 14             15              0               0      False      False
# 15             16              0               0      False      False
# 16             17              0               0      False      False
# 17             18              0               0      False      False
# 18             19              0               0      False      False
# 19             20              0               0      False      False
# 20             21              0               0      False      False
# 21             22              0               0      False      False
# 22             23              0               0      False      False
# 23             24              0               0      False      False
# 24             25              0               0      False      False
# 25             26              0               0      False      False
# 26             27              0               0      False      False
# 27             28              0               0      False      False
# 28             29              0               0      False      False
# 29             30              0               0      False       True
# ...           ...            ...             ...        ...        ...
# 51420  <a href="http://twitter.com/download/iphone" r...      False
# 51421  <a href="http://twitter.com/download/iphone" r...      False
# 51422  <a href="http://twitter.com/download/android" ...      False
# 51423  <a href="http://twitter.com/download/iphone" r...      False
# 51424  <a href="http://twitter.com/download/android" ...      False
#
#                            created_at  in_reply_to_status_id_str  \
# 0      Thu Jun 07 01:13:25 +0000 2018                        NaN
# 1      Thu Jun 07 01:13:25 +0000 2018                        NaN
# 2      Thu Jun 07 01:13:25 +0000 2018                        NaN
# 3      Thu Jun 07 01:13:25 +0000 2018                        NaN
# 4      Thu Jun 07 01:13:25 +0000 2018                        NaN
# 5      Thu Jun 07 01:13:25 +0000 2018                        NaN
# 6      Thu Jun 07 01:13:25 +0000 2018                        NaN
# 7      Thu Jun 07 01:13:25 +0000 2018                        NaN
# 8      Thu Jun 07 01:13:25 +0000 2018                        NaN
# 9      Thu Jun 07 01:13:25 +0000 2018                        NaN
# 10     Thu Jun 07 01:13:25 +0000 2018                        NaN
# 11     Thu Jun 07 01:13:26 +0000 2018                        NaN
# 12     Thu Jun 07 01:13:25 +0000 2018                        NaN
# 13     Thu Jun 07 01:13:26 +0000 2018                        NaN
# 14     Thu Jun 07 01:13:26 +0000 2018                        NaN
# 15     Thu Jun 07 01:13:26 +0000 2018                        NaN
# 16     Thu Jun 07 01:13:26 +0000 2018                        NaN
# 17     Thu Jun 07 01:13:26 +0000 2018                        NaN
# 18     Thu Jun 07 01:13:26 +0000 2018                        NaN
# 19     Thu Jun 07 01:13:26 +0000 2018                        NaN
# 20     Thu Jun 07 01:13:26 +0000 2018                        NaN
# 21     Thu Jun 07 01:13:26 +0000 2018                        NaN
# 22     Thu Jun 07 01:13:27 +0000 2018                        NaN
# 23     Thu Jun 07 01:13:27 +0000 2018                        NaN
# 24     Thu Jun 07 01:13:27 +0000 2018                        NaN
# 25     Thu Jun 07 01:13:28 +0000 2018                        NaN
# 26     Thu Jun 07 01:13:28 +0000 2018                        NaN
# 27     Thu Jun 07 01:13:28 +0000 2018                        NaN
# 28     Thu Jun 07 01:13:28 +0000 2018                        NaN
# 29     Thu Jun 07 01:13:28 +0000 2018                        NaN
# ...                               ...                        ...
# 51395  Thu Jun 07 01:58:22 +0000 2018                        NaN
# 51396  Thu Jun 07 01:58:21 +0000 2018                        NaN
# 51397  Thu Jun 07 01:58:22 +0000 2018                        NaN
# 51398  Thu Jun 07 01:58:21 +0000 2018                        NaN
# 51399  Thu Jun 07 01:58:22 +0000 2018                        NaN
# 51400  Thu Jun 07 01:58:22 +0000 2018                        NaN
# 51401  Thu Jun 07 01:58:22 +0000 2018                        NaN
# 51402  Thu Jun 07 01:58:22 +0000 2018                        NaN
# 51403  Thu Jun 07 01:58:22 +0000 2018                        NaN
# 51404  Thu Jun 07 01:58:22 +0000 2018                        NaN
# 51405  Thu Jun 07 01:58:22 +0000 2018                        NaN
# 51406  Thu Jun 07 01:58:22 +0000 2018                        NaN
# 51407  Thu Jun 07 01:58:21 +0000 2018                        NaN
# 51408  Thu Jun 07 01:58:22 +0000 2018                        NaN
# 51409  Thu Jun 07 01:58:22 +0000 2018                        NaN
# 51410  Thu Jun 07 01:58:23 +0000 2018                        NaN
# 51411  Thu Jun 07 01:58:23 +0000 2018                        NaN
# 51412  Thu Jun 07 01:58:23 +0000 2018                        NaN
# 51413  Thu Jun 07 01:58:23 +0000 2018                        NaN
# 51414  Thu Jun 07 01:58:23 +0000 2018                        NaN
# 51415  Thu Jun 07 01:58:23 +0000 2018                        NaN
# 51416  Thu Jun 07 01:58:23 +0000 2018                        NaN
# 51417  Thu Jun 07 01:58:23 +0000 2018                        NaN
# 51418  Thu Jun 07 01:58:23 +0000 2018                        NaN
# 51419  Thu Jun 07 01:58:23 +0000 2018                        NaN
# 51420  Thu Jun 07 01:58:24 +0000 2018                        NaN
# 51421  Thu Jun 07 01:58:24 +0000 2018                        NaN
# 51422  Thu Jun 07 01:58:24 +0000 2018                        NaN
# 51423  Thu Jun 07 01:58:24 +0000 2018                        NaN
# 51424  Thu Jun 07 01:58:24 +0000 2018                        NaN
#
#        in_reply_to_user_id_str lang  listed_count  verified  \
# 0                          NaN   en             7     False
# 1                          NaN   pt             1     False
# 2                          NaN   en             0     False
# 3                          NaN   en             4     False
# 4                          NaN   en             1     False
# 5                          NaN  und             2     False
# 6                          NaN   en             0     False
# 7                          NaN   en             0     False
# 8                          NaN   en             0     False
# 9                          NaN   en             2     False
# 10                         NaN   en             7     False
# 11                         NaN   en             9     False
# 12                         NaN   en           254     False
# 13                         NaN   en             1     False
# 14                         NaN   en            10     False
# 15                         NaN   en           114      True
# 16                         NaN   es            13     False
# 17                         NaN   en             6     False
# 18                         NaN   es             7     False
# 19                         NaN   en             0     False
# 20                         NaN   en             1     False
# 21                         NaN   en             0     False
# 22                         NaN   en             1     False
# 23                         NaN   ar             0     False
# 24                         NaN  und             0     False
# 25                         NaN   en             0     False
# 26                         NaN  und             3     False
# 27                         NaN   en             4     False
# 28                         NaN   pt            11     False
# 29                         NaN   es             4     False
# ...                        ...  ...           ...       ...
# 51395                      NaN   es             0     False
# 51396                      NaN   ar             3     False
# 51397                      NaN   pt             0     False
# 51398                      NaN   en             0     False
# 51399                      NaN   ar             4     False
# 51400                      NaN   en             0     False
# 51401                      NaN   en             0     False
# 51402                      NaN   en             1     False
# 51403                      NaN   en             2     False
# 51404                      NaN   en             9     False
# 51405                      NaN   es             0     False
# 51406                      NaN   en             5     False
# 51407                      NaN   tl             0     False
# 51408                      NaN   pt             0     False
# 51409                      NaN   en            22     False
# 51410                      NaN   en             0     False
# 51411                      NaN   en             0     False
# 51412                      NaN   en             0     False
# 51413                      NaN   en             6     False
# 51414                      NaN   en            21     False
# 51415                      NaN  und             0     False
# 51416                      NaN   en             0     False
# 51417                      NaN  und             6     False
# 51418                      NaN   en             1     False
# 51419                      NaN   in             3     False
# 51420                      NaN   en             0     False
# 51421                      NaN   en             1     False
# 51422                      NaN   en             3     False
# 51423                      NaN  und             5     False
# 51424                      NaN   en             0     False
#
#                                                 location          user_id_str  \
# 0                                                    NaN            234888800
# 1                                 Rio de Janeiro, Brasil   860068072983592964
# 2                                Naga City, Bicol Region   878451665258414080
# 3                                        Niterói, Brasil           3473700207
# 4                                           Lawrence, MA   951834224646086656
# 5                                                   Oran           2192745893
# 6                                 DC fan. HUGE comic fan   746466910997450754
# 7                                                    NaN            378037026
# 8                                                    NaN           3335759413
# 9                                      Daytona Beach, FL           2296293959
# 10                                           WITH A BEAR           3384925947
# 11                                                   NaN           2265500936
# 12                                   in or around Dallas            133319303
# 13                                                   NaN   984847107956838401
# 14                                      Los Angeles , CA            199513461
# 15                                           Philippines            522909551
# 16                                              La Plata            151095681
# 17                                                 Tokyo           4875434631
# 18                            Los Mochis Zapopan Sinaloa             74043956
# 19                                                Canada           2326370076
# 20                                                   NaN   949547893152624640
# 21                                                   NaN   999472788095123456
# 22                                                   NaN           2849404375
# 23     <U+0627><U+0644><U+0645><U+0645><U+0644><U+064...           4461827237
# 24                                                   NaN             66907604
# 25                                     Guarulhos, Brasil           2351471549
# 26                                        Minnesota, USA           1689084810
# 27                                          Brooklyn, NY             71312757
# 28                                 Florianópolis, Brasil           4540456456
# 29                                                   NaN           2428124411
# ...                                                  ...                  ...
# 51395                                         Rio Cuarto            183024903
# 51396                                                NaN  1000986450974867456
# 51397                                             Brasil   970357866199764992
# 51398                            somewhere down the road   862666221908512768
# 51399                                                NaN           1271814386
# 51400                                      Knoxville, TN   868471877622280195
# 51401                                        Spokane, WA           4509203363
# 51402                                        Raleigh, NC            597853762
# 51403                                                NaN            269560863
# 51404                                                NaN            336144498
# 51405                                                NaN           2869654064
# 51406                                         SP-BRAZA!              49024544
# 51407                                 Glan, Soccsksargen   969740810726998018
# 51408                                                NaN   885332999163793408
# 51409                                     Long Beach, CA            327739087
# 51410                                      Covington, LA           2616840835
# 51411                                    Aguilas, España           1254086161
# 51412                            uranus, milkyway galaxy   811133335204265984
# 51413                                                NaN            932718654
# 51414  Chitré, PAN <ed><U+00A0><U+00BC><ed><U+00B7><U...            285123484
# 51415                                    Ossa de Montiel            282961479
# 51416                                                NaN   841084367367680001
# 51417                                             Sodor             387813149
# 51418                                    Whitby, Ontario           4585934532
# 51419                                    Mersin, Türkiye           1893606030
# 51420                                         Eugene, OR   817456401698131972
# 51421                Tianjin, People's Republic of China            246602837
# 51422                                  TamilNadu Indian            2908041535
# 51423                              San Juan, Puerto Rico           2717261267
# 51424                             Santa Catarina, Brasil   983737575633506305
#
#                                              description  geo_enabled  \
# 0      I am Ava :)) ?I LOVE #TWD #FTWD just a gal ???...         True
# 1      +5521?2.0\r\n Flamenguista  nao sou so mais um...         True
# 2                                                    NaN        False
# 3                                              @Flamengo        False
# 4                                                    22?         True
# 5                                                    NaN        False
# 6      For the strength of the pack is the wolf And t...         True
# 7      Blessed wife and mother.  Cleveland fan since ...        False
# 8      Once|Colors|Words|Melodies\r\n| | | | | | | | ...        False
# 9                                                    NaN         True
# 10                                              Funkster        False
# 11                            It's all about Demi Lovato         True
# 12     I put words together. Comics, RPGs, scary movi...        False
# 13     Boteco de velho, raiz, onde ta permitido enche...        False
# 14     What's up folks I'm Jesse  born ,raise and a n...        False
# 15     The official Twitter account of @rapplerdotcom...         True
# 16     Mido 1.79 de alto y de ancho no me dio el cent...         True
# 17                                            Be you....         True
# 18     Comunicador, amante de los deportes, el cine y...         True
# 19                         What am I doing with my life?         True
# 20                                   need advice? dm me.         True
# 21                                           NEW ACCOUNT        False
# 22     Follow my IG ||yvsosa__ #SnowGang ????????????...         True
# 23                              1902 | RM  ??1927 | itti        False
# 24     We are passionate about the Supernatural. and ...        False
# 25     eu tenho azar no jogo azar na sorte e azar no ...        False
# 26                        APSU WBB #24 | follow @MEACH4L         True
# 27     From The Outside Looking In You Might Think I ...         True
# 28     Fa do Batman e Star Wars, torcedor do  Corinth...         True
# 29     Agradecida de Dios.feliz porque el me eligio p...        False
# ...                                                  ...          ...
# 51395  Papa de Cristian, Tobias y Ciro // Canal Quatr...        False
# 51396  Unofficial Account of NBA ????? ???? ????? ???...        False
# 51397  Eu venho no twitter pra reclamar da vida e fal...        False
# 51398  hiii pangga @Espanto2001 . 9/3/17 . 10/8/17 . ...        False
# 51399                                             #JFT74         True
# 51400  Contact: jimmyscheeks@gmail.com 5 college stud...         True
# 51401               I just want a big bag of Doritos ???         True
# 51402         North Carolina State '20 - Army ROTC - 11B         True
# 51403  Mi deber en este mundo es demostrarles a todos...         True
# 51404                                    I love sports.          True
# 51405                                                NaN        False
# 51406  Baller | PG | NBA Nerd | Podcast Addicted | Vi...         True
# 51407                              Music & Entertainment         True
# 51408  a vida me fez Flamengo e eu fiz do Flamengo a ...        False
# 51409  Salvadorian/ Peruvian ????Sports Fanatic Can I...         True
# 51410                      SPS '18. #24era Sc(D_Allen32)         True
# 51411  La libertad es la posesion segura de aquellos ...        False
# 51412                           on the come up, no doubt         True
# 51413   tentando nao dar o meu melhor na minha pior fase         True
# 51414      cada vez que te miro a los ojos tengo un plan         True
# 51415  Me gustan los videojuegos y el futbol. Madridi...         True
# 51416                              Music & Entertainment        False
# 51417  #UVA  #804 #DaysOfSummer \r\n Hard on coons. A...         True
# 51418                          Hebrews 13:6\r\nDream Big         True
# 51419            I'm a veteran, the youngest to be exact         True
# 51420                           Bigger Duck than Puddles        False
# 51421               Your love story is what you make it!         True
# 51422                                                NaN         True
# 51423                            Ig: nicolemarie4 ?/  x          True
# 51424                seja feliz independente de tudo! ??        False
#
#                       user_created_at  statuses_count  followers_count  \
# 0      Thu Jan 06 20:41:19 +0000 2011            5860              285
# 1      Thu May 04 09:46:22 +0000 2017            2200              113
# 2      Sat Jun 24 03:16:12 +0000 2017             578              380
# 3      Fri Aug 28 21:58:35 +0000 2015           67308              520
# 4      Fri Jan 12 15:12:18 +0000 2018           10357              805
# 5      Sat Nov 23 13:56:24 +0000 2013            9996              118
# 6      Fri Jun 24 22:15:55 +0000 2016             888               49
# 7      Thu Sep 22 14:51:42 +0000 2011            1497               18
# 8      Tue Aug 25 09:05:45 +0000 2015            2471               95
# 9      Tue Jan 21 22:13:14 +0000 2014            5992              133
# 10     Mon Jul 20 20:58:15 +0000 2015            6222              811
# 11     Sat Dec 28 07:00:11 +0000 2013           84547              635
# 1                  1963      False
# 2                   736      False
# 3                 17161      False
# 4                  4057      False
# 5                  3629      False
# 6                   767      False
# 7                  1723      False
# 8                  7451      False
# 9                 14386      False
# 10                 4815      False
# 11                11966      False
# 12                50547      False
# 13                  172      False
# 14                  604      False
# 15                  107      False
# 16                26211      False
# 17                 8670      False
# 18                  354      False
# 19                 1349      False
# 20                 1540      False
# 21                    7      False
# 22                18072      False
# 23                  149      False
# 24                   11      False
# 25                 3617      False
# 26                 2481      False
# 27                   16      False
# 28                10715      False
# 29                12416      False
# ...                 ...        ...
# 51395              1260      False
# 51396                 0      False
# 51397               775      False
# 51398              2351      False
# 51399              4964      False
# 51400               327      False
# 51401              3894      False
# 51402              8785      False
# 51403             20359      False
# 51404             50298      False
# 51405                23      False
# 51406               276      False
# 51407                87      False
# 51408              2121      False
# 51409             22553      False
# 51410              1995      False
# 51411            106457      False
# 51412               746      False
# 51413             27724      False
# 51414             20848      False
# 51415               892      False
# 51416                 0      False
# 51417             38503      False
# 51418             21910      False
# 51419                15      False
# 51420              5582      False
# 51421               628      False
# 51422             48676      False
# 51423              2099      False
# 51424               770      False
#
#                                            user_url  \
# 0                                               NaN
# 1                                               NaN
# 2                    http://Instagram.com/wrenzjudd
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
# 10                                              NaN
# 11                                              NaN
# 12           http://www.thefellowshipofthegeeks.net
# 13                   https://facebook.com/barbill6/
# 14     https://www.instagram.com/losangelesnation20
# 15                        http://rappler.com/sports
# 16          https://www.facebook.com/gonza.pantaleo
# 17                    https://www.hudl.com/v/28QkKX
# 18             http://vimeo.com/user10064451/videos
# 19                                              NaN
# 20                                              NaN
# 21                                              NaN
# 22                                              NaN
# 23                                              NaN
# 24                                              NaN
# 25                                              NaN
# 26                                              NaN
# 27                 http://Instagram.com/get2it_Kelz
# 28                                              NaN
# 29                                              NaN
# ...                                             ...
# 51395                                           NaN
# 51396                                           NaN
# 51397                                           NaN
# 51398                                           NaN
# 51399                                           NaN
# 51400                       http://jimmyscheeks.com
# 51401                                           NaN
# 51402                                           NaN
# 51403                                           NaN
# 51404                                           NaN
# 51405                                           NaN
# 51406          http://www.facebook.com/Danisantana8
# 51407                                           NaN
# 51408                                           NaN
# 51409                http://Instagram.com/purrrrdyp
# 51410                                           NaN
# 51411            https://dreakero2222.wordpress.com
# 51412                                           NaN
# 51413                                           NaN
# 51414                http://Instagram.com/sir.vidal
# 51415                                           NaN
# 51416                                           NaN
# 51417                                           NaN
# 51418                                           NaN
# 51419            http://Instagram.com/mustafatekeee
# 51420                                           NaN
# 51421                                           NaN
# 51422        https://m.facebook.com/mani.mankatha.5
# 51423                                           NaN
# 51424          http://instagram.com/gabrielbadesso_
#
#                                                     name  time_zone user_lang  \
# 0                                                    Ava        NaN        en
# 1                                               Markinho        NaN        pt
# 2                                               WR E N Z        NaN        en
# 3                                                     GB        NaN        pt
# 4                                                     NG        NaN        en
# 5          tobi <ed><U+00A0><U+00BD><ed><U+00B1><U+0081>        NaN        fr
# 6      Cole Rolan<ed><U+00A0><U+00BC><ed><U+00BE><U+0...        NaN        en
# 7                                                 Morgan        NaN        en
# 8                                           letsgotomarx        NaN        en
# 9                                               courtney        NaN        en
# 10                                         _SpaceCowboy_        NaN        es
# 11                                                  Rica        NaN        en
# 12                                           Mike Marlow        NaN        en
# 13     Bar do Bill <ed><U+00A0><U+00BC><ed><U+00BD><U...        NaN        pt
# 14                                    Los Angeles Nation        NaN        en
# 15                                        Rappler Sports        NaN        en
# 16                                                GoNzA!        NaN        es
# 17     Troyy<ed><U+00A0><U+00BD><ed><U+00B0><U+0089>...        NaN        en
# 18                                                Herloy        NaN        en
# 19                                               Boki 2K        NaN        en
# 20                                               å j e å        NaN        en
# 21                                                     Z        NaN        en
# 22     <ed><U+00A0><U+00BD><ed><U+00B2><U+0094><U+274...        NaN        en
# 23                                           fares asiri        NaN        ar
# 24                                           Geek Artist        NaN        en
# 25                                Lindissimo, falou tudo        NaN        pt
# 26     K E L E N<ed><U+00A0><U+00BE><ed><U+00B4><U+00...        NaN        en
# 27     Kelz<ed><U+00A0><U+00BC><ed><U+00B7><U+00B9><e...        NaN        en
# 28     <U+24CC><ed><U+00A0><U+00BC><ed><U+00B5><U+00B...        NaN        pt
# 29                                       Yohanna Valdez.        NaN        es
# ...                                                  ...        ...       ...
# 51395                                         Manu Merlo        NaN        es
# 51396                                             Ar_NBA        NaN        en
# 51397                                  VersagenDerGötter        NaN        pt
# 51398                                               Dee.        NaN        en
# 51399                                                  Z        NaN        en
# 51400                                     Jimmy's Cheeks        NaN        en
# 51401           <ed><U+00A0><U+00BD><ed><U+00B0><U+0090>        NaN        en
# 51402                                    Michael McGuire        NaN        en
# 51403                                     Quimey Herrera        NaN        es
# 51404                                  Andrew Greifinger        NaN        en
# 51405                                       Brian_blanco        NaN        es
# 51406                                     Daniel Santana        NaN        pt
# 51407                                             AprilG        NaN        en
# 51408                                           pelencha        NaN        pt
# 51409                                                  P        NaN        en
# 51410                                      Devonte Allen        NaN        en
# 51411                                  John Pockerstars©        NaN        es
# 51412     Tyrone<ed><U+00A0><U+00BD><ed><U+00B8><U+00B4>        NaN        en
# 51413                                              Moniz        NaN        pt
# 51414                           Orlando Vidal Bustamante        NaN        es
# 51415                                             Toivon        NaN        es
# 51416                                              logbi        NaN        en
# 51417                                Larry Holmes Status        NaN        en
# 51418                                        April Penet        NaN        en
# 51419                                           Makaveli        NaN        tr
# 51420                                         Sco Ducks        NaN        en
# 51421                                       Marvin Dalit        NaN        en
# 51422         <U+014A><U+03F0> <U+039C>a<U+0438><U+03B9>        NaN        en
# 51423     Nicko <ed><U+00A0><U+00BD><ed><U+00B1><U+0091>        NaN        en
# 51424                                           bradesco        NaN        pt
#
#        utc_offset  friends_count      screen_name country_code  \
# 0             NaN            806        avakrutko          NaN
# 1             NaN            119      Marcoosloco          NaN
# 2             NaN            319       wrenzberja          NaN
# 3             NaN            171  duartegabriel35          NaN
# 4             NaN            326         NgDaizha          NaN
# 5             NaN            118      IlyesGunner          NaN
# 6             NaN            288  thenotoriousmcr          NaN
# 7             NaN            260     morgmolenaur          NaN
# 8             NaN            240      marimmyp418          NaN
# 9             NaN            147         cma_xoxo          NaN
# 10            NaN           1986      TheGarryGuy          NaN
# 11            NaN            148   Demi4Lovaticss          NaN
# 12            NaN           7929        MikeyGeek          NaN
# 13            NaN            111       BarDoBill_          NaN
# 14            NaN           1927    RockeyJesse20          NaN
# 15            NaN            101    RapplerSports          NaN
# 16            NaN           1636        GoNzA_elp           AR
# 17            NaN            525          TI_era1          NaN
# 18            NaN            394           Herloy          NaN
# 19            NaN            165          Boki2k9          NaN
# 20            NaN            143     _airajeanine          NaN
# 21            NaN             43         MstrZeel          NaN
# 22            NaN           4820        yvsosa___          NaN
# 23            NaN            202        frose_233          NaN
# 24            NaN              1     wonderfundal          NaN
# 25            NaN            175       samucrente          NaN
# 26            NaN            364    kelen_kenol27          NaN
# 27            NaN            309      Get2It_Kelz           US
# 28            NaN            201    wlad_oliveira           BR
# 29            NaN           2198   johannamaria03          NaN
# ...           ...            ...              ...          ...
# 51395         NaN            572       ManuuMerlo          NaN
# 51396         NaN             12           ArNBA_          NaN
# 51397         NaN            235        tetningen          NaN
# 51398         NaN             85    drrnspnto_dns          NaN
# 51399         NaN            140    muhamedzinngu          NaN
# 51400         NaN            238     JimmysCheeks           US
# 51401         NaN            184         llerraf_          NaN
# ...
# 51409         NaN            870   BAULAPARRANTES          NaN
# 51410         NaN            497  Devonte_Allen24          NaN
# 51411         NaN            961    dreakeroh2222          NaN
# 51412         NaN            186     luistyrone01          NaN
# 51413         NaN            381    gabrielmonizc          NaN
# 51414         NaN           1181         SirVidal          NaN
# 51415         NaN            266       ivanossa98          NaN
# 51416         NaN             91    nmrpngnbnbrgs          NaN
# 51417         NaN            356           804_V_          NaN
# 51418         NaN            226  AprilPenetrante          NaN
# 51419         NaN             81     mutidiculous          NaN
# 51420         NaN            920   quackerforlife          NaN
# 51421         NaN            196        marvdalit          NaN
# 51422         NaN           2852           NxMani          NaN
# 51423         NaN            162       nnnnicole4          NaN
# 51424         NaN            168  gabrielbadesso_          NaN
#
#                            country place_type              full_name  \
# 0                              NaN        NaN                    NaN
# 1                              NaN        NaN                    NaN
# 2                              NaN        NaN                    NaN
# 3                              NaN        NaN                    NaN
# 4                              NaN        NaN                    NaN
# 5                              NaN        NaN                    NaN
# 6                              NaN        NaN                    NaN
# 7                              NaN        NaN                    NaN
# 8                              NaN        NaN                    NaN
# 9                              NaN        NaN                    NaN
# 10                             NaN        NaN                    NaN
# 11                             NaN        NaN                    NaN
# 12                             NaN        NaN                    NaN
# 13                             NaN        NaN                    NaN
# 14                             NaN        NaN                    NaN
# 15                             NaN        NaN                    NaN
# 16                       Argentina       city    La Plata, Argentina
# 17                             NaN        NaN                    NaN
# 18                             NaN        NaN                    NaN
# 19                             NaN        NaN                    NaN
# 20                             NaN        NaN                    NaN
# 21                             NaN        NaN                    NaN
# 22                             NaN        NaN                    NaN
# 23                             NaN        NaN                    NaN
# 24                             NaN        NaN                    NaN
# 25                             NaN        NaN                    NaN
# 26                             NaN        NaN                    NaN
# 27                   United States       city           Brooklyn, NY
# 28                          Brasil       city  Florianópolis, Brasil
# 29                             NaN        NaN                    NaN
# ...                            ...        ...                    ...
# 51395                          NaN        NaN                    NaN
# 51396                          NaN        NaN                    NaN
# 51397                          NaN        NaN                    NaN
# 51398            NaN               NaN        NaN         NaN  NaN  NaN
# 51399            NaN               NaN        NaN         NaN  NaN  NaN
# 51400      Knoxville  6565298bcadb82a1  35.982471  -83.963842  NaN  NaN
# 51401            NaN               NaN        NaN         NaN  NaN  NaN
# 51402            NaN               NaN        NaN         NaN  NaN  NaN
# 51403            NaN               NaN        NaN         NaN  NaN  NaN
# 51404            NaN               NaN        NaN         NaN  NaN  NaN
# 51405            NaN               NaN        NaN         NaN  NaN  NaN
# 51406            NaN               NaN        NaN         NaN  NaN  NaN
# 51407           Glan  00cc434e3ffcfaff   5.737996  125.329414  NaN  NaN
# 51408            NaN               NaN        NaN         NaN  NaN  NaN
# 51409            NaN               NaN        NaN         NaN  NaN  NaN
# 51410            NaN               NaN        NaN         NaN  NaN  NaN
# 51411            NaN               NaN        NaN         NaN  NaN  NaN
# 51412            NaN               NaN        NaN         NaN  NaN  NaN
# 51413            NaN               NaN        NaN         NaN  NaN  NaN
# 51414            NaN               NaN        NaN         NaN  NaN  NaN
# 51415            NaN               NaN        NaN         NaN  NaN  NaN
# 51416            NaN               NaN        NaN         NaN  NaN  NaN
# 51417            NaN               NaN        NaN         NaN  NaN  NaN
# 51418            NaN               NaN        NaN         NaN  NaN  NaN
# 51419            NaN               NaN        NaN         NaN  NaN  NaN
# 51420            NaN               NaN        NaN         NaN  NaN  NaN
# 51421            NaN               NaN        NaN         NaN  NaN  NaN
# 51422            NaN               NaN        NaN         NaN  NaN  NaN
# 51423            NaN               NaN        NaN         NaN  NaN  NaN
# 51424            NaN               NaN        NaN         NaN  NaN  NaN
#
#                                             expanded_url  \
# 0                                                    NaN
# 1      https://twitter.com/NBA/status/100447552030887...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7      https://twitter.com/923TheFan/status/100453143...
# 8      https://twitter.com/NBA/status/100453114430449...
# 9                                                    NaN
# 10     https://www.sportsinformationnetwork.com/free-...
# 11                                                   NaN
# 12     https://itunes.apple.com/us/podcast/the-real-d...
# 13                                                   NaN
# 14                                                   NaN
# 15     https://www.rappler.com/sports/by-sport/basket...
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24     https://rover.ebay.com/rover/0/0/0?mpre=https%...
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29     https://twitter.com/i/web/status/1004531755435...
# ...                                                  ...
# 51395                                                NaN
# 51396                                                NaN
# 51397                                                NaN
# 51398                                                NaN
# 51399                                                NaN
# 51400                                                NaN
# 51401                                                NaN
# 51402                                                NaN
# 51403                                                NaN
# 51404                                                NaN
# 51405                                                NaN
# 51406                                                NaN
# 51407                                                NaN
# 51408  https://twitter.com/bleacherreport/status/1004...
# 51409                                                NaN
# 51410  https://twitter.com/nba/status/100448897022554...
# 51411                                                NaN
# 51412                                                NaN
# 51413                                                NaN
# 51414                                                NaN
# 51415                                                NaN
# 51416                                                NaN
# 51417                                                NaN
# 51418                                                NaN
# 51419                                                NaN
# 51420                                                NaN
# 51421                                                NaN
# 51422                                                NaN
# 51423  https://twitter.com/bleacherreport/status/1004...
# 51424                                                NaN
#
#                            url
# 0                          NaN
# 1      https://t.co/wPgRLwdg1O
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7      https://t.co/TbT5NvBquI
# 8      https://t.co/ZNgsPWcc9Z
# 9                          NaN
# 10     https://t.co/EAlnXMZcrZ
# 11                         NaN
# 12     https://t.co/0B2cXoBWx9
# 13                         NaN
# 14                         NaN
# 15     https://t.co/Yf7yapEKPj
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# 20                         NaN
# 21                         NaN
# 22                         NaN
# 23                         NaN
# 24     https://t.co/QBBrHOm77s
# 25                         NaN
# 26                         NaN
# 27                         NaN
# 28                         NaN
# 29     https://t.co/VS3QhsL7xv
# ...                        ...
# 51395                      NaN
# 51396                      NaN
# 51397                      NaN
# 51398                      NaN
# 51399                      NaN
# 51400                      NaN
# 51401                      NaN
# 51402                      NaN
# 51403                      NaN
# 51404                      NaN
# 51405                      NaN
# 51406                      NaN
# 51407                      NaN
# 51408  https://t.co/KaMcUUmzcp
# 51409                      NaN
# 51410  https://t.co/m0EnyFKcFh
# 51411                      NaN
# 51412                      NaN
# 51413                      NaN
# 51414                      NaN
# 51415                      NaN
# 51416                      NaN
# 51417                      NaN
# 51418                      NaN
# 51419                      NaN
# 51420                      NaN
# 51421                      NaN
# 51422                      NaN
# 51423  https://t.co/mrT5JMngl4
# 51424                      NaN
#
# [51425 rows x 43 columns]

# %%
#this line of code did not work - it said drop(columns = [list])
#changes to specify axis and labels instead of columns. make sure this is reflected in the textbook
tweets = tweets.drop(axis=1, labels=["Unnamed: 0", "utc_offset", "id_str", "url", "expanded_url", "user_id_str", "in_reply_to_screen_name", 
                             "in_reply_to_status_id_str", "in_reply_to_user_id_str"])

# %%
tweets.head()
# Out:
#                                                 text  retweet_count  \
# 0  RT @cavs: #NBAFinals GAME 3 STARTERS:\r\n\r\n@...              0
# 1  Ja comecou e eu no onibus  https://t.co/wPgRLw...              0
# 2    lets go Cavs\r\n#WhateverItTakes \r\n#NBAFinals              0
# 3  RT @cavs: #NBAFinals GAME 3 STARTERS:\r\n\r\n@...              0
# 4  RT @NBA:  Count down @StephenCurry30's TOP 5 t...              0
#
#    favorite_count  favorited  truncated  \
# 0               0      False      False
# 1               0      False      False
# 2               0      False      False
# 3               0      False      False
# 4               0      False      False
#
#                                               source  retweeted  \
# 0  <a href="http://twitter.com/download/iphone" r...      False
# 1  <a href="http://twitter.com/download/android" ...      False
# 2  <a href="http://twitter.com/download/android" ...      False
# 3  <a href="http://twitter.com/download/android" ...      False
# 4  <a href="http://twitter.com/download/iphone" r...      False
#
#                        created_at lang  listed_count  verified  \
# 0  Thu Jun 07 01:13:25 +0000 2018   en             7     False
# 1  Thu Jun 07 01:13:25 +0000 2018   pt             1     False
# 2  Thu Jun 07 01:13:25 +0000 2018   en             0     False
# 3  Thu Jun 07 01:13:25 +0000 2018   en             4     False
# 4  Thu Jun 07 01:13:25 +0000 2018   en             1     False
#
#                   location                                        description  \
# 0                      NaN  I am Ava :)) ?I LOVE #TWD #FTWD just a gal ???...
# 1   Rio de Janeiro, Brasil  +5521?2.0\r\n Flamenguista  nao sou so mais um...
# 2  Naga City, Bicol Region                                                NaN
# 3          Niterói, Brasil                                          @Flamengo
# 4             Lawrence, MA                                                22?
#
#    geo_enabled                 user_created_at  statuses_count  \
# 0         True  Thu Jan 06 20:41:19 +0000 2011            5860
# 1         True  Thu May 04 09:46:22 +0000 2017            2200
# 2        False  Sat Jun 24 03:16:12 +0000 2017             578
# 3        False  Fri Aug 28 21:58:35 +0000 2015           67308
# 4         True  Fri Jan 12 15:12:18 +0000 2018           10357
#
#    followers_count  favourites_count  protected  \
# 0              285             12836      False
# 1              113              1963      False
# 2              380               736      False
# 3              520             17161      False
# 4              805              4057      False
#
#                          user_url      name  time_zone user_lang  \
# 0                             NaN       Ava        NaN        en
# 1                             NaN  Markinho        NaN        pt
# 2  http://Instagram.com/wrenzjudd  WR E N Z        NaN        en
# 3                             NaN        GB        NaN        pt
# 4                             NaN        NG        NaN        en
#
#    friends_count      screen_name country_code country place_type full_name  \
# 0            806        avakrutko          NaN     NaN        NaN       NaN
# 1            119      Marcoosloco          NaN     NaN        NaN       NaN
# 2            319       wrenzberja          NaN     NaN        NaN       NaN
# 3            171  duartegabriel35          NaN     NaN        NaN       NaN
# 4            326         NgDaizha          NaN     NaN        NaN       NaN
#
#   place_name place_id  place_lat  place_lon  lat  lon
# 0        NaN      NaN        NaN        NaN  NaN  NaN
# 1        NaN      NaN        NaN        NaN  NaN  NaN
# 2        NaN      NaN        NaN        NaN  NaN  NaN
# 3        NaN      NaN        NaN        NaN  NaN  NaN
# 4        NaN      NaN        NaN        NaN  NaN  NaN

# %% [markdown]
# # Basic Manipulation

# %%
tweets.head()
# Out:
#                                                 text  retweet_count  \
# 0  RT @cavs: #NBAFinals GAME 3 STARTERS:\r\n\r\n@...              0
# 1  Ja comecou e eu no onibus  https://t.co/wPgRLw...              0
# 2    lets go Cavs\r\n#WhateverItTakes \r\n#NBAFinals              0
# 3  RT @cavs: #NBAFinals GAME 3 STARTERS:\r\n\r\n@...              0
# 4  RT @NBA:  Count down @StephenCurry30's TOP 5 t...              0
#
#    favorite_count  favorited  truncated  \
# 0               0      False      False
# 1               0      False      False
# 2               0      False      False
# 3               0      False      False
# 4               0      False      False
#
#                                               source  retweeted  \
# 0  <a href="http://twitter.com/download/iphone" r...      False
# 1  <a href="http://twitter.com/download/android" ...      False
# 2  <a href="http://twitter.com/download/android" ...      False
# 3  <a href="http://twitter.com/download/android" ...      False
# 4  <a href="http://twitter.com/download/iphone" r...      False
#
#                        created_at lang  listed_count  verified  \
# 0  Thu Jun 07 01:13:25 +0000 2018   en             7     False
# 1  Thu Jun 07 01:13:25 +0000 2018   pt             1     False
# 2  Thu Jun 07 01:13:25 +0000 2018   en             0     False
# 3  Thu Jun 07 01:13:25 +0000 2018   en             4     False
# 4  Thu Jun 07 01:13:25 +0000 2018   en             1     False
#
#                   location                                        description  \
# 0                      NaN  I am Ava :)) ?I LOVE #TWD #FTWD just a gal ???...
# 1   Rio de Janeiro, Brasil  +5521?2.0\r\n Flamenguista  nao sou so mais um...
# 2  Naga City, Bicol Region                                                NaN
# 3          Niterói, Brasil                                          @Flamengo
# 4             Lawrence, MA                                                22?
#
#    geo_enabled                 user_created_at  statuses_count  \
# 0         True  Thu Jan 06 20:41:19 +0000 2011            5860
# 1         True  Thu May 04 09:46:22 +0000 2017            2200
# 2        False  Sat Jun 24 03:16:12 +0000 2017             578
# 3        False  Fri Aug 28 21:58:35 +0000 2015           67308
# 4         True  Fri Jan 12 15:12:18 +0000 2018           10357
#
#    followers_count  favourites_count  protected  \
# 0              285             12836      False
# 1              113              1963      False
# 2              380               736      False
# 3              520             17161      False
# 4              805              4057      False
#
#                          user_url      name  time_zone user_lang  \
# 0                             NaN       Ava        NaN        en
# 1                             NaN  Markinho        NaN        pt
# 2  http://Instagram.com/wrenzjudd  WR E N Z        NaN        en
# 3                             NaN        GB        NaN        pt
# 4                             NaN        NG        NaN        en
#
#    friends_count      screen_name country_code country place_type full_name  \
# 0            806        avakrutko          NaN     NaN        NaN       NaN
# 1            119      Marcoosloco          NaN     NaN        NaN       NaN
# 2            319       wrenzberja          NaN     NaN        NaN       NaN
# 3            171  duartegabriel35          NaN     NaN        NaN       NaN
# 4            326         NgDaizha          NaN     NaN        NaN       NaN
#
#   place_name place_id  place_lat  place_lon  lat  lon
# 0        NaN      NaN        NaN        NaN  NaN  NaN
# 1        NaN      NaN        NaN        NaN  NaN  NaN
# 2        NaN      NaN        NaN        NaN  NaN  NaN
# 3        NaN      NaN        NaN        NaN  NaN  NaN
# 4        NaN      NaN        NaN        NaN  NaN  NaN

# %% [markdown]
# Looking at the shape of the dataframe allows us to get a better understanding of how many data points and how many variables we are dealing with.

# %%
tweets.shape
# Out:
# (51425, 35)

# %% [markdown]
# Recall from the textbook that we can access columns and rows in the dataframe through indexing! Let's try looking at the text of the 5th tweet of our dataframe.

# %%
tweets['text'].iloc[5]

##what do we want them to notice about this tweet? also the URL doesn't exist. 
#can we find another RT that has a working link? could be cool!
# Out:
# 'RT @NBA: \r\n\r\n#NBAFinals \r\n#WhateverItTakes https://t.co/izrz82gkzm'

# %% [markdown]
# What do you notice about the tweet?

# %% [markdown]
# *Double click here to begin typing your answer*

# %% [markdown]
# When dealing with large datasets, it's more helpful to get a big picture idea so we know what data we are dealing with. We can do this through a series of visualizations and summary statistics.

# %%
max(tweets['retweet_count'])
# Out:
# 0

# %%
sns.countplot(x='lang', data=tweets)
plt.xticks(rotation=90);

# %%
# add description about why the visual generated above is not good because we can not compare the other languages as well with this scale/ focusing on such large disparities
sns.countplot(x='lang', data=tweets[tweets['lang'].isin(['en', 'pt', 'und', 'es', 'ar', 'tr', 'fr', 'tl'])])
plt.xticks(rotation=90);

# %%
# length of each tweet
tweets['length'] = tweets['text'].str.len()

# %%
plt.hist(tweets['length'])
plt.title('Distribtion of Tweet Lengths');

#maybe either add a desciption or a question for them to describe this histogram. what can they say about tweet length after looking at this histogram?

# %%
plt.scatter(tweets['followers_count'], tweets['friends_count'])
#for their sake, we should label this 
#or challenge them to label this

# %% [markdown]
# In the next section we focus on eliminating NA data - add description / section heading here

# %%
# dealing with null data
tweets['location']
# Out:
# 0                                                      NaN
# 1                                   Rio de Janeiro, Brasil
# 2                                  Naga City, Bicol Region
# 3                                          Niterói, Brasil
# 4                                             Lawrence, MA
# 5                                                     Oran
# 6                                   DC fan. HUGE comic fan
# 7                                                      NaN
# 8                                                      NaN
# 9                                        Daytona Beach, FL
# 10                                             WITH A BEAR
# 11                                                     NaN
# 12                                     in or around Dallas
# 13                                                     NaN
# 14                                        Los Angeles , CA
# 15                                             Philippines
# 16                                                La Plata
# 17                                                   Tokyo
# 18                              Los Mochis Zapopan Sinaloa
# 19                                                  Canada
# 20                                                     NaN
# 21                                                     NaN
# 22                                                     NaN
# 23       <U+0627><U+0644><U+0645><U+0645><U+0644><U+064...
# 24                                                     NaN
# 25                                       Guarulhos, Brasil
# 26                                          Minnesota, USA
# 27                                            Brooklyn, NY
# 28                                   Florianópolis, Brasil
# 29                                                     NaN
#                                ...
# 51395                                           Rio Cuarto
# 51396                                                  NaN
# 51397                                               Brasil
# 51398                              somewhere down the road
# 51399                                                  NaN
# 51400                                        Knoxville, TN
# 51401                                          Spokane, WA
# 51402                                          Raleigh, NC
# 51403                                                  NaN
# 51404                                                  NaN
# 51405                                                  NaN
# 51406                                           SP-BRAZA!
# 51407                                   Glan, Soccsksargen
# 51408                                                  NaN
# 51409                                       Long Beach, CA
# 51410                                        Covington, LA
# 51411                                      Aguilas, España
# 51412                              uranus, milkyway galaxy
# 51413                                                  NaN
# 51414    Chitré, PAN <ed><U+00A0><U+00BC><ed><U+00B7><U...
# 51415                                      Ossa de Montiel
# 51416                                                  NaN
# 51417                                               Sodor
# 51418                                      Whitby, Ontario
# 51419                                      Mersin, Türkiye
# 51420                                           Eugene, OR
# 51421                  Tianjin, People's Republic of China
# 51422                                    TamilNadu Indian
# 51423                                San Juan, Puerto Rico
# 51424                               Santa Catarina, Brasil
# Name: location, Length: 51425, dtype: object

# %%
np.count_nonzero(tweets['location'].isna())
# Out:
# 14487

# %%
tweets['location'] = tweets['location'].fillna('No Location')

# %%
tweets['location']
# Out:
# 0                                              No Location
# 1                                   Rio de Janeiro, Brasil
# 2                                  Naga City, Bicol Region
# 3                                          Niterói, Brasil
# 4                                             Lawrence, MA
# 5                                                     Oran
# 6                                   DC fan. HUGE comic fan
# 7                                              No Location
# 8                                              No Location
# 9                                        Daytona Beach, FL
# 10                                             WITH A BEAR
# 11                                             No Location
# 12                                     in or around Dallas
# 13                                             No Location
# 14                                        Los Angeles , CA
# 15                                             Philippines
# 16                                                La Plata
# 17                                                   Tokyo
# 18                              Los Mochis Zapopan Sinaloa
# 19                                                  Canada
# 20                                             No Location
# 21                                             No Location
# 22                                             No Location
# 23       <U+0627><U+0644><U+0645><U+0645><U+0644><U+064...
# 24                                             No Location
# 25                                       Guarulhos, Brasil
# 26                                          Minnesota, USA
# 27                                            Brooklyn, NY
# 28                                   Florianópolis, Brasil
# 29                                             No Location
#                                ...
# 51395                                           Rio Cuarto
# 51396                                          No Location
# 51397                                               Brasil
# 51398                              somewhere down the road
# 51399                                          No Location
# 51400                                        Knoxville, TN
# 51401                                          Spokane, WA
# 51402                                          Raleigh, NC
# 51403                                          No Location
# 51404                                          No Location
# 51405                                          No Location
# 51406                                           SP-BRAZA!
# 51407                                   Glan, Soccsksargen
# 51408                                          No Location
# 51409                                       Long Beach, CA
# 51410                                        Covington, LA
# 51411                                      Aguilas, España
# 51412                              uranus, milkyway galaxy
# 51413                                          No Location
# 51414    Chitré, PAN <ed><U+00A0><U+00BC><ed><U+00B7><U...
# 51415                                      Ossa de Montiel
# 51416                                          No Location
# 51417                                               Sodor
# 51418                                      Whitby, Ontario
# 51419                                      Mersin, Türkiye
# 51420                                           Eugene, OR
# 51421                  Tianjin, People's Republic of China
# 51422                                    TamilNadu Indian
# 51423                                San Juan, Puerto Rico
# 51424                               Santa Catarina, Brasil
# Name: location, Length: 51425, dtype: object

# %% [markdown]
# ## Group By and Aggregations

# %% [markdown]
# We use "groupby" and "aggregate" to group and represent data based on a certain field value. Imagine if you had a dataset with each entry being a person in your class and the color they like. If you wanted to answer the question regarding how many people like the color pink, you would have to group by the color and aggregate the number of people.
#
# #should we define the term aggregate with other math words they may know? is this done in the textbook?

# %% [markdown]
# Similarly, in regards to the the nba tweets dataset, let's say we want to look at how many people tweeted in a certain language. First step would be to group by tweet.

# %%
grouped_by_lang = tweets[["text", "lang"]].groupby("lang")

# %%
grouped_by_lang

# %% [markdown]
# As you can see above, grouped_by_lang does not look like a dataframe yet - it is actually a groupby object until we apply an aggregation method like sum, count, average or similar on the group by object. Because in this case we are only looking at how many people tweeted, we can use a simple count function as our aggregator.

# %%
count_by_lang = grouped_by_lang.agg(np.count_nonzero).sort_values("text", ascending=False).head()
count_by_lang
# Out:
#        text
# lang
# en    37756
# und    3237
# es     3164
# ar     2129
# pt     1901

# %% [markdown]
# Notice that the entries in the lang field are bolded, and when you try to access the column, it returns a key error as below.

# %%
count_by_lang["lang"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'lang'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-c6b82821aa35> in <module>()
# ----> 1 count_by_lang["lang"]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'lang'

# %% [markdown]
# This is because use a groupby on a certain field, make it the index in the resulting dataframe. So if you would like to acccess the lang field, we must reset the index.

# %%
count_by_lang_reset_index = count_by_lang.reset_index()
count_by_lang_reset_index
# Out:
#   lang   text
# 0   en  37756
# 1  und   3237
# 2   es   3164
# 3   ar   2129
# 4   pt   1901

# %% [markdown]
# Now we can access the lang field.

# %%
list(count_by_lang_reset_index["lang"])
# Out:
# ['en', 'und', 'es', 'ar', 'pt']

# %% [markdown]
# As we can see, as we can expect english is the most common language among all the tweets.

# %% [markdown]
# How about trying to find out the number of tweets per country in the dataset? Replace the values wherever you see an "..."

# %%
grouped_by_country_code = tweets["...."].groupby("....")
count_by_country_code = grouped_by_country_code.agg("...")
count_by_country_code.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '....'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-22f78edb5636> in <module>()
# ----> 1 grouped_by_country_code = tweets["...."].groupby("....")
#       2 count_by_country_code = grouped_by_country_code.agg("...")
#       3 count_by_country_code.head()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '....'

# %% [markdown]
# Sort the values in count_by_country_code and find out the top 5 countries that tweet about the NBA. Assign the answer variable below, to a list of these countries.

# %%
answer_max_country_engagement = [...]
answer_max_country_engagement

# %% [markdown]
# For the next exercise remember, the way to aggregate by a certain function, is to provide that function as an argument to the .agg method.

# %% [markdown]
# Common functions used are sum, np.count_nonzero (count), np.mean (average), and np.std (standard deviation). The example below groups by country code and returns the average number of listed count for each country. Fill in the "..." below.

# %%
grouped_by_country_code = tweets[["country_code", "listed_count"]].groupby("country_code")
grouped_by_country_code.agg(np.mean).sort_values("listed_count", ascending=False).head()
