# %% [markdown]
# # Module 6.1 Activity: Introduction to Pandas

# %% [markdown]
# ## Importing Pandas

# %% [markdown]
#  As you have seen in class, Pandas can be a very useful tool when working with tabular data and is commonly used by data scientists in the real world! In the call below, use what you know about importing packages to import Pandas! If you want to, you can abbreviate pandas to `pd` (very common in data science).

# %% [markdown]
# **Hint:** Pandas is called pandas!

# %%
import pandas as pd

# %% [markdown]
# ## Creating a Pandas DataFrame

# %% [markdown]
# Let's create a simple table like we have seen in the past. This table will have two columns: `Stores` and `Scoop Price`.

# %%
ice_cream = {"Stores": ["Coldstone", "Cream", "Baskin Robbins", "Ben and Jerry's", "Haagen Dazs"],
            "Scoop Price": [5.00, 3.50, 2.79, 3.99, 4.99]}

# %% [markdown]
# Now you need to make it into a data frame in the call below!

# %%
scoops = pd.DataFrame(ice_cream)
scoops
# Out:
#             Stores  Scoop Price
# 0        Coldstone         5.00
# 1            Cream         3.50
# 2   Baskin Robbins         2.79
# 3  Ben and Jerry's         3.99
# 4      Haagen Dazs         4.99

# %% [markdown]
# **Question 1:** How many rows will our ice_cream_df have?

# %%
number_rows = scoops.shape[0]
number_rows
# Out:
# 5

# %% [markdown]
# **Question 2:** How many columns will our table have?

# %%
number_columns = scoops.shape[1]
number_columns
# Out:
# 2

# %% [markdown]
# **Question 3:** What are the names of our two columns? For an added challenge, try to only use code to get the column names.

# %% [markdown]
# **HINT:** [https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.columns.html] may be helpful.

# %%
names = scoops.columns.values
names
# Out:
# array(['Stores', 'Scoop Price'], dtype=object)

# %% [markdown]
# **Column Names:** *Type the corresponding text for the column names here*

# %% [markdown]
# ## Importing Data Frames

# %% [markdown]
# We have a dataset called "cereal.csv". In the next line, we need to import it here so that we can use it here! Make sure to give it the name `cereal` so that we can access it easily!

# %%
cereal = pd.read_csv('cereal.csv')
cereal
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0       6     280        25      3     1.0  0.33  68.402973
# 1     8.0       8     135         0      3     1.0  1.00  33.983679
# 2     7.0       5     320        25      3     1.0  0.33  59.425505
# 3     8.0       0     330        25      3     1.0  0.50  93.704912
# 4    14.0       8      -1        25      3     1.0  0.75  34.384843
# ..    ...     ...     ...       ...    ...     ...   ...        ...
# 72   21.0       3      60        25      3     1.0  0.75  39.106174
# 73   13.0      12      25        25      2     1.0  1.00  27.753301
# 74   17.0       3     115        25      1     1.0  0.67  49.787445
# 75   17.0       3     110        25      1     1.0  1.00  51.592193
# 76   16.0       8      60        25      1     1.0  0.75  36.187559
#
# [77 rows x 16 columns]

# %% [markdown]
# Let's try to show just the first five rows of our `cereal` DataFrame. Use Pandas's `head()` method to do exactly that!

# %%
first_five = cereal.head()
first_five
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating  index
# 0    5.0       6     280        25      3     1.0  0.33  68.402973      1
# 1    8.0       8     135         0      3     1.0  1.00  33.983679      2
# 2    7.0       5     320        25      3     1.0  0.33  59.425505      3
# 3    8.0       0     330        25      3     1.0  0.50  93.704912      4
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843      5

# %% [markdown]
# ## Working with the Data

# %% [markdown]
# Now that we have our dataset let's see how we can interact with the data. When you write your answer, check and see if your code works!

# %% [markdown]
# **Question 4:** How could I return a column of just the cereal names?

# %%
cereal_names = cereal['name']
cereal_names
# Out:
# 0                     100% Bran
# 1             100% Natural Bran
# 2                      All-Bran
# 3     All-Bran with Extra Fiber
# 4                Almond Delight
#                 ...
# 72                      Triples
# 73                         Trix
# 74                   Wheat Chex
# 75                     Wheaties
# 76          Wheaties Honey Gold
# Name: name, Length: 77, dtype: object

# %% [markdown]
# **Question 5:** How could I add a new column called `index` to the data table with the index of each cereal starting at 1?

# %%
cereal['index'] = cereal.index + 1
cereal
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating  index
# 0     5.0       6     280        25      3     1.0  0.33  68.402973      1
# 1     8.0       8     135         0      3     1.0  1.00  33.983679      2
# 2     7.0       5     320        25      3     1.0  0.33  59.425505      3
# 3     8.0       0     330        25      3     1.0  0.50  93.704912      4
# 4    14.0       8      -1        25      3     1.0  0.75  34.384843      5
# ..    ...     ...     ...       ...    ...     ...   ...        ...    ...
# 72   21.0       3      60        25      3     1.0  0.75  39.106174     73
# 73   13.0      12      25        25      2     1.0  1.00  27.753301     74
# 74   17.0       3     115        25      1     1.0  0.67  49.787445     75
# 75   17.0       3     110        25      1     1.0  1.00  51.592193     76
# 76   16.0       8      60        25      1     1.0  0.75  36.187559     77
#
# [77 rows x 17 columns]

# %% [markdown]
# **Question 6:** How could I create a DataFrame that took the first 25 rows with just the `name`, `sugars`, and `rating` columns?

# %%
sugars_and_rating = cereal.loc[0:25, ['name', 'sugars', 'rating']]
sugars_and_rating.head()
# Out:
#                         name  sugars     rating
# 0                  100% Bran       6  68.402973
# 1          100% Natural Bran       8  33.983679
# 2                   All-Bran       5  59.425505
# 3  All-Bran with Extra Fiber       0  93.704912
# 4             Almond Delight       8  34.384843

# %% [markdown]
# **Challenge Question:** How could I return only the the rows for Trix?

# %%
trix = cereal.loc[cereal['name'] == 'Trix']
trix
# Out:
#     name mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  \
# 73  Trix   G    C       110        1    1     140    0.0   13.0      12
#
#     potass  vitamins  shelf  weight  cups     rating  index
# 73      25        25      2     1.0   1.0  27.753301     74
