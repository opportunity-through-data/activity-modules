# %%
import pandas as pd
import numpy as np

# %%
soccer = pd.read_csv('soccer.csv')

# %% [markdown]
# Here's cool stuff you can do with Pandas! You don't need to know how to do all of this yet, but you'll learn how to do much of it by the end of this module!

# %%
soccer_grouped = soccer.groupby('Nationality')['Name'].count()

soccer_grouped
# Out:
# Nationality
# Afghanistan      4
# Albania         40
# Algeria         60
# Andorra          1
# Angola          15
#               ...
# Uzbekistan       2
# Venezuela       67
# Wales          129
# Zambia           9
# Zimbabwe        13
# Name: Name, Length: 164, dtype: int64

# %%
soccer['Dribbling'].median()
# Out:
# 61.0

# %%
soccer.groupby('Club')['SprintSpeed'].mean().reset_index().sort_values('SprintSpeed', ascending = False)
# Out:
#                            Club  SprintSpeed
# 326                    Juventus    74.120000
# 428                         PSV    73.200000
# 86            Borussia Dortmund    73.060606
# 435         Paris Saint-Germain    72.633333
# 418          Olympique Lyonnais    72.482759
# ..                          ...          ...
# 361                 Limerick FC    57.789474
# 620                 Vissel Kobe    57.500000
# 300  Hokkaido Consadole Sapporo    56.896552
# 507              SV Mattersburg    56.615385
# 92               Bray Wanderers    52.869565
#
# [651 rows x 2 columns]

# %% [markdown]
# Now, onto our lesson!

# %%
soccer.head()
# Out:
#    Unnamed: 0               Name  Age Nationality  Overall  Potential  \
# 0           0           L. Messi   31   Argentina       94         94
# 1           1  Cristiano Ronaldo   33    Portugal       94         94
# 2           2          Neymar Jr   26      Brazil       92         93
# 3           3             De Gea   27       Spain       91         93
# 4           4       K. De Bruyne   27     Belgium       91         92
#
#                   Club Preferred Foot  International Reputation Position  ...  \
# 0         FC Barcelona           Left                       5.0       RF  ...
# 1             Juventus          Right                       5.0       ST  ...
# 2  Paris Saint-Germain          Right                       5.0       LW  ...
# 3    Manchester United          Right                       4.0       GK  ...
# 4      Manchester City          Right                       4.0      RCM  ...
#
# ...

# %%
soccer.shape #shape is an attribute so we don't call it like a function
# Out:
# (18207, 21)

# %%
soccer.loc[1:3, ['Overall', 'Club']]
# Out:
#    Overall                 Club
# 1       94             Juventus
# 2       92  Paris Saint-Germain
# 3       91    Manchester United

# %%
soccer.loc[[100, 1000, 10000], 'Name']
# Out:
# 100      Diego Costa
# 1000         A. Poli
# 10000    J. Haugaard
# Name: Name, dtype: object

# %%
soccer.loc[soccer.Overall >= 80]
# Out:
#      Unnamed: 0               Name  Age Nationality  Overall  Potential  \
# 0             0           L. Messi   31   Argentina       94         94
# 1             1  Cristiano Ronaldo   33    Portugal       94         94
# 2             2          Neymar Jr   26      Brazil       92         93
# 3             3             De Gea   27       Spain       91         93
# 4             4       K. De Bruyne   27     Belgium       91         92
# ..          ...                ...  ...         ...      ...        ...
# 550         550  B. Schweinsteiger   33     Germany       80         80
# 551         551               Moyá   34       Spain       80         80
# 552         552          W. Rooney   32     England       80         80
# 553         553    Fernando Torres   34       Spain       80         80
# 554         554      S. Sorrentino   39       Italy       80         80
#
#                     Club Preferred Foot  International Reputation Position  \
# ...

# %%
soccer.loc[soccer.Position == 'GK']
# Out:
#        Unnamed: 0           Name  Age Nationality  Overall  Potential  \
# 3               3         De Gea   27       Spain       91         93
# 9               9       J. Oblak   25    Slovenia       90         93
# 18             18  M. ter Stegen   26     Germany       89         92
# 19             19    T. Courtois   26     Belgium       89         90
# 22             22       M. Neuer   32     Germany       89         89
# ...           ...            ...  ...         ...      ...        ...
# 18178       18178   L. Wahlstedt   18      Sweden       48         65
# 18180       18180       M. Hurst   22    Scotland       48         58
# 18183       18183  K. Pilkington   44     England       48         48
# 18194       18194       J. Milli   18       Italy       47         65
# 18198       18198     J. Livesey   18     England       47         70
#
#                     Club Preferred Foot  International Reputation Position  \
# ...

# %%
soccer.loc[:, ['Age', 'Name', 'Potential']]
# Out:
#        Age                Name  Potential
# 0       31            L. Messi         94
# 1       33   Cristiano Ronaldo         94
# 2       26           Neymar Jr         93
# 3       27              De Gea         93
# 4       27        K. De Bruyne         92
# ...    ...                 ...        ...
# 18202   19        J. Lundstram         65
# 18203   19  N. Christoffersson         63
# 18204   16           B. Worman         67
# 18205   17      D. Walker-Rice         66
# 18206   16           G. Nugent         66
#
# [18207 rows x 3 columns]

# %%
soccer.iloc[1:5,10:20] #row, column
# Out:
#    Finishing  HeadingAccuracy  Dribbling  Curve  LongPassing  BallControl  \
# 1       94.0             89.0       88.0   81.0         77.0         94.0
# 2       87.0             62.0       96.0   88.0         78.0         95.0
# 3       13.0             21.0       18.0   21.0         51.0         42.0
# 4       82.0             55.0       86.0   85.0         91.0         91.0
#
#    SprintSpeed  Reactions  Stamina  Strength
# 1         91.0       96.0     88.0      79.0
# 2         90.0       94.0     81.0      49.0
# 3         58.0       90.0     43.0      64.0
# 4         76.0       91.0     90.0      75.0

# %%
soccer.iloc[1:100,[0, 1, 2, 8]]
# Out:
#     Unnamed: 0               Name  Age  International Reputation
# 1            1  Cristiano Ronaldo   33                       5.0
# 2            2          Neymar Jr   26                       5.0
# 3            3             De Gea   27                       4.0
# 4            4       K. De Bruyne   27                       4.0
# 5            5          E. Hazard   27                       4.0
# ..         ...                ...  ...                       ...
# 95          95         J. Boateng   29                       4.0
# 96          96           A. Vidal   31                       4.0
# 97          97         I. Perišić   29                       3.0
# 98          98           E. Džeko   32                       3.0
# 99          99         S. Khedira   31                       3.0
#
# [99 rows x 4 columns]
